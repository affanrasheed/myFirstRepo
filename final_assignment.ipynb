# %% [markdown]
# # Final Assignment

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### List of DataScience Languages

# %% [markdown]
# * Python
# * R
# * SQL

# %% [markdown]
# ### List of DataScience Libraries

# %% [markdown]
# * Pytorch
# * TensorFlow
# * Scikit-learn

# %% [markdown]
# ### Table of DataScience Tool

# %% [markdown]
# | Sr. No. | DataScience Tool |
# | ------- | ---------------- |
# | 1- | R Studio |
# | 2- | Jupyter |
# | 3- | Apache Spark |

# %% [markdown]
# ### Arithmetic Expression

# %% [markdown]
# $ ax^2 + bx + c = 0 $

# %% [markdown]
# ### Multiply and Add Expression

# %%
x = 3
y = 7
print(x+y)
print(x*y)
# Out:
# 10
# 21

# %% [markdown]
# ### minute to hour code

# %%
minutes = 120
hours = minutes/60
print(minutes, "mins is equal to ", hours, "hours")
# Out:
# 120 mins is equal to  2.0 hours

# %% [markdown]
# ### Objectives

# %% [markdown]
# * To understand different DataScience tools
# * To understand different DataScience languages
# * To understand differnt DataScience libraries

# %% [markdown]
# ### Author Name

# %% [markdown]
# *Muhammad Affan*
